# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0]

# %%
df= pd.concat([df1,df2,df3,df4])

# %%
df
# Out:
#             Opening  Opening.1                  Title  \
# 0     J A N U A R Y          3             The Grudge
# 1     J A N U A R Y         10             Underwater
# 2     J A N U A R Y         10            Like a Boss
# 3     J A N U A R Y         10          Three Christs
# 4     J A N U A R Y         10      Inherit the Viper
# ..              ...        ...                    ...
# 94  D E C E M B E R         25       We Can Be Heroes
# 95  D E C E M B E R         25      News of the World
# 96  D E C E M B E R         25  One Night in Miami...
# 97  D E C E M B E R         25  Promising Young Woman
# 98  D E C E M B E R         30      Pieces of a Woman
#
#                                    Production company  \
# 0   Screen Gems / Stage 6 Films / Ghost House Pict...
# 1   20th Century Fox / TSG Entertainment / Chernin...
# 2                  Paramount Pictures / Artists First
# 3                                           IFC Films
# 4   Lionsgate / Barry Films / Tycor International ...
# ..                                                ...
# 94  Netflix / Troublemaker Studios / Double R Prod...
# 95        Universal Pictures / Perfect World Pictures
# 96                                     Amazon Studios
# 97          Focus Features / FilmNation Entertainment
# 98                             Netflix / Bron Studios
#
#                                         Cast and crew  \
# 0   Nicolas Pesce (director/screenplay); Andrea Ri...
# 1   William Eubank (director); Brian Duffield, Ada...
# 2   Miguel Arteta (director); Sam Pitman, Adam Col...
# 3   Jon Avnet (director/screenplay); Eric Nazarian...
# 4   Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                                                ...
# 94  Robert Rodriguez (director/screenplay); Priyan...
# 95  Paul Greengrass (director/screenplay); Luke Da...
# 96  Regina King (director); Kemp Powers (screenpla...
# 97  Emerald Fennell (director/screenplay); Carey M...
# 98  Kornél Mundruczó (director); Kata Wéber (scree...
#
#    .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                 [2]
# 1                                                 [3]
# 2                                                 [4]
# 3                                                 NaN
# 4                                                 [5]
# ..                                                ...
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
#
#      Ref.
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 94  [243]
# 95  [244]
# 96  [245]
# 97  [246]
# 98  [247]
#
# [275 rows x 7 columns]

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df.columns
# Out:
# Index(['Opening', 'Opening.1', 'Title', 'Production company', 'Cast and crew',
#        '.mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.',
#        'Ref.'],
#       dtype='object')

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in /usr/local/lib/python3.10/dist-packages (1.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tmdbv3api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (2024.6.2)

# %%
from tmdbv3api import TMDb
import json
import requests
import os
from dotenv import load_dotenv

load_dotenv()

tmdb = TMDb()
tmdb.api_key = os.getenv('API_KEY')

# %%
from tmdbv3api import Movie
import numpy as np
import requests

tmdb_movie = Movie()

def get_genre(x):
    genres = []
    try:
        result = tmdb_movie.search(x)
        if not result:
            return np.NaN
        else:
            movie_id = result[0].id
            response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb_movie.api_key))
            data_json = response.json()
            if 'genres' in data_json and data_json['genres']:
                genre_str = " "
                for i in range(len(data_json['genres'])):
                    genres.append(data_json['genres'][i]['name'])
                return genre_str.join(genres)
            else:
                return np.NaN
    except Exception as e:
        print(f"Error processing title '{x}': {e}")
        return np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# Error processing title 'No films had been released on this date as resulting the closure of theaters caused by the COVID-19 pandemic': getattr(): attribute name must be string
# Error processing title 'Mighty Oak': getattr(): attribute name must be string
# Error processing title 'The SpongeBob Movie: Sponge on the Run (Canadian theatrical release)': getattr(): attribute name must be string
# Error processing title 'Bill & Ted Face the Music': getattr(): attribute name must be string
# Error processing title 'The Secrets We Keep': Internal error: Something went wrong, contact TMDb.
# Error processing title 'Run': getattr(): attribute name must be string
# Error processing title 'Breach': Expecting value: line 1 column 1 (char 0)
# <ipython-input-107-fdc91464740e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2020
# Out:
#                     Title                                      Cast and crew  \
# 0              The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1              Underwater  William Eubank (director); Brian Duffield, Ada...
# 2             Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3           Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4       Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                    ...                                                ...
# 94       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 95      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 96  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 97  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 98      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres
# 0                            Horror Mystery
# 1   Horror Science Fiction Action Adventure
# 2                                    Comedy
# 3                                     Drama
# 4                      Crime Thriller Drama
# ..                                      ...
# 94             Family Action Fantasy Comedy
# 95                  Drama Western Adventure
# 96                                    Drama
# 97                     Thriller Crime Drama
# 98                                    Drama
#
# [275 rows x 3 columns]

# %%
df_2020['genres'].isna().sum()
# Out:
# 12

# %%
# Assuming df_2020 is your DataFrame containing the 'genres' column
df_2020=df_2020.dropna(subset='genres')

# %%
df_2020
# Out:
#                     Title                                      Cast and crew  \
# 0              The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1              Underwater  William Eubank (director); Brian Duffield, Ada...
# 2             Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3           Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4       Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                    ...                                                ...
# 94       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 95      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 96  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 97  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 98      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres
# 0                            Horror Mystery
# 1   Horror Science Fiction Action Adventure
# 2                                    Comedy
# 3                                     Drama
# 4                      Crime Thriller Drama
# ..                                      ...
# 94             Family Action Fantasy Comedy
# 95                  Drama Western Adventure
# 96                                    Drama
# 97                     Thriller Crime Drama
# 98                                    Drama
#
# [263 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-115-bc52fe9b0c35>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# <ipython-input-117-42c5f763f942>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# <ipython-input-119-ca9c918a7840>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))
# Out:
# <ipython-input-121-db7926ce943c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                     Title                                      Cast and crew  \
# 0              The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1              Underwater  William Eubank (director); Brian Duffield, Ada...
# 2             Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3           Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4       Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                    ...                                                ...
# 94       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 95      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 96  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 97  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 98      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres     director_name  \
# 0                            Horror Mystery     Nicolas Pesce
# 1   Horror Science Fiction Action Adventure    William Eubank
# 2                                    Comedy     Miguel Arteta
# 3                                     Drama         Jon Avnet
# 4                      Crime Thriller Drama    Anthony Jerjen
# ..                                      ...               ...
# 94             Family Action Fantasy Comedy  Robert Rodriguez
# 95                  Drama Western Adventure   Paul Greengrass
# 96                                    Drama       Regina King
# 97                     Thriller Crime Drama   Emerald Fennell
# 98                                    Drama  Kornél Mundruczó
#
#              actor_1_name       actor_2_name     actor_3_name
# 0      Andrea Riseborough      Demián Bichir         John Cho
# 1         Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2         Tiffany Haddish         Rose Byrne      Salma Hayek
# 3            Richard Gere     Peter Dinklage   Walton Goggins
# 4           Josh Hartnett  Margarita Levieva   Chandler Riggs
# ..                    ...                ...              ...
# 94  Priyanka Chopra Jonas       Pedro Pascal    YaYa Gosselin
# 95              Tom Hanks      Helena Zengel              NaN
# 96      Kingsley Ben-Adir          Eli Goree      Aldis Hodge
# 97         Carey Mulligan         Bo Burnham      Alison Brie
# 98          Vanessa Kirby       Shia LaBeouf     Molly Parker
#
# [263 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#        director_name           actor_1_name       actor_2_name  \
# 0      Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1     William Eubank        Kristen Stewart     Vincent Cassel
# 2      Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3          Jon Avnet           Richard Gere     Peter Dinklage
# 4     Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..               ...                    ...                ...
# 94  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 95   Paul Greengrass              Tom Hanks      Helena Zengel
# 96       Regina King      Kingsley Ben-Adir          Eli Goree
# 97   Emerald Fennell         Carey Mulligan         Bo Burnham
# 98  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#        actor_3_name                                   genres  \
# 0          John Cho                           Horror Mystery
# 1   Jessica Henwick  Horror Science Fiction Action Adventure
# 2       Salma Hayek                                   Comedy
# 3    Walton Goggins                                    Drama
# 4    Chandler Riggs                     Crime Thriller Drama
# ..              ...                                      ...
# 94    YaYa Gosselin             Family Action Fantasy Comedy
# 95              NaN                  Drama Western Adventure
# 96      Aldis Hodge                                    Drama
# 97      Alison Brie                     Thriller Crime Drama
# 98     Molly Parker                                    Drama
#
#               movie_title
# 0              The Grudge
# 1              Underwater
# 2             Like a Boss
# 3           Three Christs
# 4       Inherit the Viper
# ..                    ...
# 94       We Can Be Heroes
# 95      News of the World
# 96  One Night in Miami...
# 97  Promising Young Woman
# 98      Pieces of a Woman
#
# [263 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      4
# actor_3_name     27
# genres            0
# movie_title       0
# comb             27
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# <ipython-input-130-83e83e91073b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20
# Out:
#        director_name           actor_1_name       actor_2_name  \
# 0      Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1     William Eubank        Kristen Stewart     Vincent Cassel
# 2      Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3          Jon Avnet           Richard Gere     Peter Dinklage
# 4     Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..               ...                    ...                ...
# 93       Pete Docter             Jamie Foxx           Tina Fey
# 94  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 96       Regina King      Kingsley Ben-Adir          Eli Goree
# 97   Emerald Fennell         Carey Mulligan         Bo Burnham
# 98  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#        actor_3_name                                   genres  \
# 0          John Cho                           Horror Mystery
# 1   Jessica Henwick  Horror Science Fiction Action Adventure
# 2       Salma Hayek                                   Comedy
# 3    Walton Goggins                                    Drama
# 4    Chandler Riggs                     Crime Thriller Drama
# ..              ...                                      ...
# 93    Graham Norton          Animation Family Comedy Fantasy
# 94    YaYa Gosselin             Family Action Fantasy Comedy
# 96      Aldis Hodge                                    Drama
# 97      Alison Brie                     Thriller Crime Drama
# 98     Molly Parker                                    Drama
#
#               movie_title                                               comb
# 0              the grudge  Andrea Riseborough Demián Bichir John Cho Nico...
# 1              underwater  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2             like a boss  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3           three christs  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4       inherit the viper  Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                    ...                                                ...
# 93                   soul  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 94       we can be heroes  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 96  one night in miami...  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 97  promising young woman  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 98      pieces of a woman  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [236 rows x 7 columns]

# %%
old_df=pd.read_csv('final_data.csv')

# %%
old_df
# Out:
#                        director_name       actor_1_name          actor_2_name  \
# 0     Joachim Rønning Espen Sandberg        Johnny Depp         Javier Bardem
# 1                        Zack Snyder        Ben Affleck          Henry Cavill
# 2                      Taika Waititi    Chris Hemsworth        Tom Hiddleston
# 3                         James Gunn        Chris Pratt           Zoe Saldana
# 4                      Sean McNamara     Pierce Brosnan          William Hurt
# ...                              ...                ...                   ...
# 5854          Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5855                    Greta Gerwig      Saoirse Ronan           Emma Watson
# 5856                      Sam Mendes      George MacKay  Dean-Charles Chapman
# 5857           Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5858                 Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#          actor_3_name                                    genres  \
# 0       Geoffrey Rush           Adventure Action Fantasy Comedy
# 1           Gal Gadot           Action Adventure Fantasy Sci-Fi
# 2      Cate Blanchett           Action Adventure Fantasy Sci-Fi
# 3       Dave Bautista            Action Adventure Comedy Sci-Fi
# 4     Benjamin Walker                  Fantasy Action Adventure
# ...               ...                                       ...
# 5854    Rashida Jones  Animation Action Adventure Comedy Family
# 5855    Florence Pugh                             Drama Romance
# 5856      Mark Strong                  War Action Drama History
# 5857      Brie Larson                       Drama Crime History
# 5858      Aldis Hodge                                     Drama
#
#                                            movie_title  \
# 0     pirates of the caribbean: dead men tell no tales
# 1                                       justice league
# 2                                       thor: ragnarok
# 3                       guardians of the galaxy vol. 2
# 4                                  the king's daughter
# ...                                                ...
# 5854                                 spies in disguise
# 5855                                      little women
# 5856                                              1917
# 5857                                        just mercy
# 5858                                          clemency
#
#                                                    comb
# 0     Johnny Depp Javier Bardem Geoffrey Rush Joachi...
# 1     Ben Affleck Henry Cavill Gal Gadot Zack Snyder...
# 2     Chris Hemsworth Tom Hiddleston Cate Blanchett ...
# 3     Chris Pratt Zoe Saldana Dave Bautista James Gu...
# 4     Pierce Brosnan William Hurt Benjamin Walker Se...
# ...                                                 ...
# 5854  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5855  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5856  George MacKay Dean-Charles Chapman Mark Strong...
# 5857  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5858  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5859 rows x 7 columns]

# %%
final_df=pd.concat([old_df,new_df20])

# %%
final_df
# Out:
#                      director_name           actor_1_name    actor_2_name  \
# 0   Joachim Rønning Espen Sandberg            Johnny Depp   Javier Bardem
# 1                      Zack Snyder            Ben Affleck    Henry Cavill
# 2                    Taika Waititi        Chris Hemsworth  Tom Hiddleston
# 3                       James Gunn            Chris Pratt     Zoe Saldana
# 4                    Sean McNamara         Pierce Brosnan    William Hurt
# ..                             ...                    ...             ...
# 93                     Pete Docter             Jamie Foxx        Tina Fey
# 94                Robert Rodriguez  Priyanka Chopra Jonas    Pedro Pascal
# 96                     Regina King      Kingsley Ben-Adir       Eli Goree
# 97                 Emerald Fennell         Carey Mulligan      Bo Burnham
# 98                Kornél Mundruczó          Vanessa Kirby    Shia LaBeouf
#
#        actor_3_name                           genres  \
# 0     Geoffrey Rush  Adventure Action Fantasy Comedy
# 1         Gal Gadot  Action Adventure Fantasy Sci-Fi
# 2    Cate Blanchett  Action Adventure Fantasy Sci-Fi
# 3     Dave Bautista   Action Adventure Comedy Sci-Fi
# 4   Benjamin Walker         Fantasy Action Adventure
# ..              ...                              ...
# 93    Graham Norton  Animation Family Comedy Fantasy
# 94    YaYa Gosselin     Family Action Fantasy Comedy
# 96      Aldis Hodge                            Drama
# 97      Alison Brie             Thriller Crime Drama
# 98     Molly Parker                            Drama
#
#                                          movie_title  \
# 0   pirates of the caribbean: dead men tell no tales
# 1                                     justice league
# 2                                     thor: ragnarok
# 3                     guardians of the galaxy vol. 2
# 4                                the king's daughter
# ..                                               ...
# 93                                              soul
# 94                                  we can be heroes
# 96                             one night in miami...
# 97                             promising young woman
# 98                                 pieces of a woman
#
#                                                  comb
# 0   Johnny Depp Javier Bardem Geoffrey Rush Joachi...
# 1   Ben Affleck Henry Cavill Gal Gadot Zack Snyder...
# 2   Chris Hemsworth Tom Hiddleston Cate Blanchett ...
# 3   Chris Pratt Zoe Saldana Dave Bautista James Gu...
# 4   Pierce Brosnan William Hurt Benjamin Walker Se...
# ..                                                ...
# 93  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 94  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 96  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 97  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 98  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [6095 rows x 7 columns]

# %%
final_df.to_csv('updated_data.csv',index=False)
