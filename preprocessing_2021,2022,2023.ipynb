# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0]

# %%
df= pd.concat([df1,df2,df3,df4])

# %%
df
# Out:
#             Opening  Opening.1                            Title  \
# 0     J A N U A R Y        1.0              Shadow in the Cloud
# 1     J A N U A R Y        5.0                          Hacksaw
# 2     J A N U A R Y       12.0  Dr. Bird's Advice for Sad Poets
# 3     J A N U A R Y       13.0                  The White Tiger
# 4     J A N U A R Y       14.0                      Locked Down
# ..              ...        ...                              ...
# 93  D E C E M B E R       25.0           The Tragedy of Macbeth
# 94  D E C E M B E R       25.0             A Journal for Jordan
# 95  D E C E M B E R       25.0                American Underdog
# 96  D E C E M B E R       26.0                          Memoria
# 97  D E C E M B E R        NaN                              NaN
#
#                                    Production company  \
# 0                              Vertical Entertainment
# 1                    Leone Films / Midnight Releasing
# 2            Relativity Media / Ketchup Entertainment
# 3            Netflix / ARRAY / Purple Pebble Pictures
# 4                     HBO Max / Warner Bros. Pictures
# ..                                                ...
# 93                        Apple TV+ / A24 / IAC Films
# 94  Columbia Pictures / Escape Artists / Bron Studios
# 95                                          Lionsgate
# 96                                               Neon
# 97                                                NaN
#
#                                         Cast and crew  \
# 0   Roseanne Liang (director/screenplay); Max Land...
# 1   Anthony Leone (director/screenplay); Amy Cay, ...
# 2   Yaniv Raz (director/screenplay); Lucas Jade Zu...
# 3   Ramin Bahrani (director/screenplay); Adarsh Go...
# 4   Doug Liman (director); Steven Knight (screenpl...
# ..                                                ...
# 93  Joel Coen (director/screenplay); Denzel Washin...
# 94  Denzel Washington (director); Virgil Williams ...
# 95  Erwin brothers (directors); Jon Erwin, David A...
# 96  Apichatpong Weerasethakul (director/acreenplay...
# 97                                                NaN
#
#    .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                 [2]
# 1                                                 [3]
# 2                                                 [4]
# 3                                                 NaN
# 4                                                 [5]
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#      Ref.
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 93  [277]
# 94  [278]
# 95  [279]
# 96  [280]
# 97    NaN
#
# [365 rows x 7 columns]

# %%
df_2021 = df[['Title','Cast and crew']]

# %%
# !pip install tmdbv3api
# Out:
# Collecting tmdbv3api
#   Downloading tmdbv3api-1.9.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tmdbv3api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (2024.6.2)
# Installing collected packages: tmdbv3api
# Successfully installed tmdbv3api-1.9.0

# %%
from tmdbv3api import TMDb
import json
import requests
import os
from dotenv import load_dotenv

load_dotenv()

tmdb = TMDb()
tmdb.api_key = os.getenv('API_KEY')

# %%
from tmdbv3api import Movie
import numpy as np
import requests

tmdb_movie = Movie()

def get_genre(x):
    genres = []
    try:
        result = tmdb_movie.search(x)
        if not result:
            return np.NaN
        else:
            movie_id = result[0].id
            response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb_movie.api_key))
            data_json = response.json()
            if 'genres' in data_json and data_json['genres']:
                genre_str = " "
                for i in range(len(data_json['genres'])):
                    genres.append(data_json['genres'][i]['name'])
                return genre_str.join(genres)
            else:
                return np.NaN
    except Exception as e:
        print(f"Error processing title '{x}': {e}")
        return np.NaN

# %%
df_2021['genres'] = df_2021['Title'].map(lambda x: get_genre(str(x)))
# Out:
# Error processing title 'Wish Dragon': getattr(): attribute name must be string
# Error processing title 'Dating and New York': getattr(): attribute name must be string
# <ipython-input-12-252c1cda1e49>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['genres'] = df_2021['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2021
# Out:
#                               Title  \
# 0               Shadow in the Cloud
# 1                           Hacksaw
# 2   Dr. Bird's Advice for Sad Poets
# 3                   The White Tiger
# 4                       Locked Down
# ..                              ...
# 93           The Tragedy of Macbeth
# 94             A Journal for Jordan
# 95                American Underdog
# 96                          Memoria
# 97                              NaN
#
#                                         Cast and crew  \
# 0   Roseanne Liang (director/screenplay); Max Land...
# 1   Anthony Leone (director/screenplay); Amy Cay, ...
# 2   Yaniv Raz (director/screenplay); Lucas Jade Zu...
# 3   Ramin Bahrani (director/screenplay); Adarsh Go...
# 4   Doug Liman (director); Steven Knight (screenpl...
# ..                                                ...
# 93  Joel Coen (director/screenplay); Denzel Washin...
# 94  Denzel Washington (director); Virgil Williams ...
# 95  Erwin brothers (directors); Jon Erwin, David A...
# 96  Apichatpong Weerasethakul (director/acreenplay...
# 97                                                NaN
#
#                                genres
# 0                   Horror Action War
# 1   Adventure Family TV Movie Western
# 2                        Comedy Drama
# 3                               Drama
# 4                Comedy Crime Romance
# ..                                ...
# 93                          Drama War
# 94                      Drama Romance
# 95                              Drama
# 96      Drama Science Fiction Mystery
# 97                        Drama Crime
#
# [365 rows x 3 columns]

# %%
df_2021['genres'].isna().sum()
# Out:
# 3

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-16-059d9cfe3ca6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# <ipython-input-18-fbf9a4980306>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# <ipython-input-20-597eaf6de001>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2021 = df_2021.rename(columns={'Title':'movie_title'})

# %%
new_df21 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df21
# Out:
#                                         director_name  \
# 0                                      Roseanne Liang
# 1                                       Anthony Leone
# 2                                           Yaniv Raz
# 3                                       Ramin Bahrani
# 4                                          Doug Liman
# ..                                                ...
# 93                                          Joel Coen
# 94                                  Denzel Washington
# 95                                     Erwin brothers
# 96  Apichatpong Weerasethakul (director/acreenplay...
# 97                                                nan
#
#                                          actor_1_name          actor_2_name  \
# 0                                  Chloë Grace Moretz     Taylor John Smith
# 1                                             Amy Cay  Brian Patrick Butler
# 2                                   Lucas Jade Zumann        Taylor Russell
# 3                                       Adarsh Gourav         Rajkummar Rao
# 4                                       Anne Hathaway      Chiwetel Ejiofor
# ..                                                ...                   ...
# 93                                  Denzel Washington     Frances McDormand
# 94                                  Michael B. Jordan          Chanté Adams
# 95                                       Zachary Levi           Anna Paquin
# 96  Apichatpong Weerasethakul (director/acreenplay...            Elkin Díaz
# 97                                                nan                   NaN
#
#              actor_3_name                             genres  \
# 0            Beulah Koale                  Horror Action War
# 1      Michael C. Burgess  Adventure Family TV Movie Western
# 2            Chase Stokes                       Comedy Drama
# 3   Priyanka Chopra Jonas                              Drama
# 4        Stephen Merchant               Comedy Crime Romance
# ..                    ...                                ...
# 93          Bertie Carvel                          Drama War
# 94        Jalon Christian                      Drama Romance
# 95           Dennis Quaid                              Drama
# 96         Jeanne Balibar      Drama Science Fiction Mystery
# 97                    NaN                        Drama Crime
#
#                         movie_title
# 0               Shadow in the Cloud
# 1                           Hacksaw
# 2   Dr. Bird's Advice for Sad Poets
# 3                   The White Tiger
# 4                       Locked Down
# ..                              ...
# 93           The Tragedy of Macbeth
# 94             A Journal for Jordan
# 95                American Underdog
# 96                          Memoria
# 97                              NaN
#
# [365 rows x 6 columns]

# %%
new_df21['comb'] = new_df21['actor_1_name'] + ' ' + new_df21['actor_2_name'] + ' '+ new_df21['actor_3_name'] + ' '+ new_df21['director_name'] +' ' + new_df21['genres']

# %%
new_df21.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      8
# actor_3_name     26
# genres            3
# movie_title       1
# comb             28
# dtype: int64

# %%
new_df21 = new_df21.dropna(how='any')

# %%
new_df21.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df21['movie_title'] = new_df21['movie_title'].str.lower()
# Out:
# <ipython-input-30-6e765124d575>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df21['movie_title'] = new_df21['movie_title'].str.lower()

# %%
new_df21
# Out:
#                                         director_name  \
# 0                                      Roseanne Liang
# 1                                       Anthony Leone
# 2                                           Yaniv Raz
# 3                                       Ramin Bahrani
# 4                                          Doug Liman
# ..                                                ...
# 92                                     Matthew Vaughn
# 93                                          Joel Coen
# 94                                  Denzel Washington
# 95                                     Erwin brothers
# 96  Apichatpong Weerasethakul (director/acreenplay...
#
#                                          actor_1_name          actor_2_name  \
# 0                                  Chloë Grace Moretz     Taylor John Smith
# 1                                             Amy Cay  Brian Patrick Butler
# 2                                   Lucas Jade Zumann        Taylor Russell
# 3                                       Adarsh Gourav         Rajkummar Rao
# 4                                       Anne Hathaway      Chiwetel Ejiofor
# ..                                                ...                   ...
# 92                                      Ralph Fiennes        Gemma Arterton
# 93                                  Denzel Washington     Frances McDormand
# 94                                  Michael B. Jordan          Chanté Adams
# 95                                       Zachary Levi           Anna Paquin
# 96  Apichatpong Weerasethakul (director/acreenplay...            Elkin Díaz
#
#              actor_3_name                             genres  \
# 0            Beulah Koale                  Horror Action War
# 1      Michael C. Burgess  Adventure Family TV Movie Western
# 2            Chase Stokes                       Comedy Drama
# 3   Priyanka Chopra Jonas                              Drama
# 4        Stephen Merchant               Comedy Crime Romance
# ..                    ...                                ...
# 92             Rhys Ifans   Action Comedy Adventure Thriller
# 93          Bertie Carvel                          Drama War
# 94        Jalon Christian                      Drama Romance
# 95           Dennis Quaid                              Drama
# 96         Jeanne Balibar      Drama Science Fiction Mystery
#
#                         movie_title  \
# 0               shadow in the cloud
# 1                           hacksaw
# 2   dr. bird's advice for sad poets
# 3                   the white tiger
# 4                       locked down
# ..                              ...
# 92                   the king's man
# 93           the tragedy of macbeth
# 94             a journal for jordan
# 95                american underdog
# 96                          memoria
#
#                                                  comb
# 0   Chloë Grace Moretz Taylor John Smith Beulah Ko...
# 1   Amy Cay Brian Patrick Butler Michael C. Burges...
# 2   Lucas Jade Zumann Taylor Russell Chase Stokes ...
# 3   Adarsh Gourav Rajkummar Rao Priyanka Chopra Jo...
# 4   Anne Hathaway Chiwetel Ejiofor Stephen Merchan...
# ..                                                ...
# 92  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 93  Denzel Washington Frances McDormand Bertie Car...
# 94  Michael B. Jordan Chanté Adams Jalon Christian...
# 95  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 96  Apichatpong Weerasethakul (director/acreenplay...
#
# [337 rows x 7 columns]

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0]

# %%
df= pd.concat([df1,df2,df3,df4])

# %%
df
# Out:
#             Opening  Opening.1                     Title  \
# 0     J A N U A R Y        7.0                   The 355
# 1     J A N U A R Y        7.0  The Legend of La Llorona
# 2     J A N U A R Y        7.0              The Commando
# 3     J A N U A R Y        7.0            American Siege
# 4     J A N U A R Y       14.0                    Scream
# ..              ...        ...                       ...
# 86  D E C E M B E R       30.0            Alice, Darling
# 87  D E C E M B E R        NaN                       NaN
# 88  D E C E M B E R        NaN                       NaN
# 89  D E C E M B E R        NaN                       NaN
# 90  D E C E M B E R        NaN                       NaN
#
#                                    Production company  \
# 0   Universal Pictures / Freckle Films / FilmNatio...
# 1                      Saban Films / Ageless Pictures
# 2                Saban Films / Premiere Entertainment
# 3                              Vertical Entertainment
# 4   Paramount Pictures / Spyglass Media Group / Ra...
# ..                                                ...
# 86                     Lionsgate / Elevation Pictures
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
#
#                                         Cast and crew  \
# 0   Simon Kinberg (director/screenplay); Theresa R...
# 1   Patricia Harris Seeley (director); José Prende...
# 2   Asif Akbar (director); Koji Steven Sakai (scre...
# 3   Edward John Drake (director/screenplay); Timot...
# 4   Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                ...
# 86  Mary Nighy (director); Alanna Francis (screenp...
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
#
#    .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                 [2]
# 1                                                 [3]
# 2                                                 [4]
# 3                                                 [5]
# 4                                                 [6]
# ..                                                ...
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
#
#      Ref.
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 86  [261]
# 87    NaN
# 88    NaN
# 89    NaN
# 90    NaN
#
# [317 rows x 7 columns]

# %%
df_2022 = df[['Title','Cast and crew']]

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in /usr/local/lib/python3.10/dist-packages (1.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tmdbv3api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (2024.6.2)

# %%
from tmdbv3api import TMDb
import json
import requests
import os
from dotenv import load_dotenv

load_dotenv()

tmdb = TMDb()
tmdb.api_key = os.getenv('API_KEY')

# %%
from tmdbv3api import Movie
import numpy as np
import requests

tmdb_movie = Movie()

def get_genre(x):
    genres = []
    try:
        result = tmdb_movie.search(x)
        if not result:
            return np.NaN
        else:
            movie_id = result[0].id
            response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb_movie.api_key))
            data_json = response.json()
            if 'genres' in data_json and data_json['genres']:
                genre_str = " "
                for i in range(len(data_json['genres'])):
                    genres.append(data_json['genres'][i]['name'])
                return genre_str.join(genres)
            else:
                return np.NaN
    except Exception as e:
        print(f"Error processing title '{x}': {e}")
        return np.NaN

# %%
df_2022['genres'] = df_2022['Title'].map(lambda x: get_genre(str(x)))
# Out:
# Error processing title 'Apollo 10 1⁄2: A Space Age Childhood': getattr(): attribute name must be string
# <ipython-input-42-4e8e2d4797da>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['genres'] = df_2022['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2022['genres'].isna().sum()
# Out:
# 1

# %%
df_2022
# Out:
#                        Title  \
# 0                    The 355
# 1   The Legend of La Llorona
# 2               The Commando
# 3             American Siege
# 4                     Scream
# ..                       ...
# 86            Alice, Darling
# 87                       NaN
# 88                       NaN
# 89                       NaN
# 90                       NaN
#
#                                         Cast and crew  \
# 0   Simon Kinberg (director/screenplay); Theresa R...
# 1   Patricia Harris Seeley (director); José Prende...
# 2   Asif Akbar (director); Koji Steven Sakai (scre...
# 3   Edward John Drake (director/screenplay); Timot...
# 4   Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                ...
# 86  Mary Nighy (director); Alanna Francis (screenp...
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
#
#                              genres
# 0                   Action Thriller
# 1   Family Animation Fantasy Horror
# 2             Action Crime Thriller
# 3         Action Adventure Thriller
# 4              Crime Horror Mystery
# ..                              ...
# 86           Thriller Drama Romance
# 87                      Drama Crime
# 88                      Drama Crime
# 89                      Drama Crime
# 90                      Drama Crime
#
# [317 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-46-bde37e357dd2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# <ipython-input-48-e67b31464e65>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# <ipython-input-50-d3d5c35d26fc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2022['actor_3_name'] = df_2022['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2022 = df_2022.rename(columns={'Title':'movie_title'})

# %%
new_df22 = df_2022.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df22
# Out:
#                            director_name       actor_1_name  \
# 0                          Simon Kinberg   Jessica Chastain
# 1                 Patricia Harris Seeley      Autumn Reeser
# 2                             Asif Akbar      Mickey Rourke
# 3                      Edward John Drake  Timothy V. Murphy
# 4   Matt Bettinelli-Olpin, Tyler Gillett    Melissa Barrera
# ..                                   ...                ...
# 86                            Mary Nighy      Anna Kendrick
# 87                                   nan                nan
# 88                                   nan                nan
# 89                                   nan                nan
# 90                                   nan                nan
#
#          actor_2_name     actor_3_name                           genres  \
# 0       Penélope Cruz     Fan Bingbing                  Action Thriller
# 1         Danny Trejo     Antonio Cupo  Family Animation Fantasy Horror
# 2   Michael Jai White              NaN            Action Crime Thriller
# 3        Bruce Willis        Rob Gough        Action Adventure Thriller
# 4       Mason Gooding     Jenna Ortega             Crime Horror Mystery
# ..                ...              ...                              ...
# 86    Kaniehtiio Horn  Charlie Carrick           Thriller Drama Romance
# 87                NaN              NaN                      Drama Crime
# 88                NaN              NaN                      Drama Crime
# 89                NaN              NaN                      Drama Crime
# 90                NaN              NaN                      Drama Crime
#
#                  movie_title
# 0                    The 355
# 1   The Legend of La Llorona
# 2               The Commando
# 3             American Siege
# 4                     Scream
# ..                       ...
# 86            Alice, Darling
# 87                       NaN
# 88                       NaN
# 89                       NaN
# 90                       NaN
#
# [317 rows x 6 columns]

# %%
new_df22['comb'] = new_df22['actor_1_name'] + ' ' + new_df22['actor_2_name'] + ' '+ new_df22['actor_3_name'] + ' '+ new_df22['director_name'] +' ' + new_df22['genres']

# %%
new_df22.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name     11
# actor_3_name     34
# genres            1
# movie_title       4
# comb             35
# dtype: int64

# %%
new_df22 = new_df22.dropna(how='any')

# %%
new_df22.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df22['movie_title'] = new_df22['movie_title'].str.lower()
# Out:
# <ipython-input-61-bd701421fe8d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df22['movie_title'] = new_df22['movie_title'].str.lower()

# %%
new_df22
# Out:
#                            director_name       actor_1_name     actor_2_name  \
# 0                          Simon Kinberg   Jessica Chastain    Penélope Cruz
# 1                 Patricia Harris Seeley      Autumn Reeser      Danny Trejo
# 3                      Edward John Drake  Timothy V. Murphy     Bruce Willis
# 4   Matt Bettinelli-Olpin, Tyler Gillett    Melissa Barrera    Mason Gooding
# 5          Derek Drymon, Jennifer Kluska       Andy Samberg     Selena Gomez
# ..                                   ...                ...              ...
# 82                          Kasi Lemmons        Naomi Ackie    Stanley Tucci
# 83                          Scott Cooper     Christian Bale    Harry Melling
# 84                          Sarah Polley        Rooney Mara       Claire Foy
# 85                          Marc Forster          Tom Hanks  Mariana Treviño
# 86                            Mary Nighy      Anna Kendrick  Kaniehtiio Horn
#
#         actor_3_name                                     genres  \
# 0       Fan Bingbing                            Action Thriller
# 1       Antonio Cupo            Family Animation Fantasy Horror
# 3          Rob Gough                  Action Adventure Thriller
# 4       Jenna Ortega                       Crime Horror Mystery
# 5       Kathryn Hahn  Animation Comedy Family Adventure Fantasy
# ..               ...                                        ...
# 82    Ashton Sanders                        Music History Drama
# 83  Gillian Anderson              Thriller Crime Horror Mystery
# 84    Jessie Buckley                                      Drama
# 85     Rachel Keller                               Comedy Drama
# 86   Charlie Carrick                     Thriller Drama Romance
#
#                                      movie_title  \
# 0                                        the 355
# 1                       the legend of la llorona
# 3                                 american siege
# 4                                         scream
# 5              hotel transylvania: transformania
# ..                                           ...
# 82  whitney houston: i wanna dance with somebody
# 83                             the pale blue eye
# 84                                 women talking
# 85                             a man called otto
# 86                                alice, darling
#
#                                                  comb
# 0   Jessica Chastain Penélope Cruz Fan Bingbing Si...
# 1   Autumn Reeser Danny Trejo Antonio Cupo Patrici...
# 3   Timothy V. Murphy Bruce Willis Rob Gough Edwar...
# 4   Melissa Barrera Mason Gooding Jenna Ortega Mat...
# 5   Andy Samberg Selena Gomez Kathryn Hahn Derek D...
# ..                                                ...
# 82  Naomi Ackie Stanley Tucci Ashton Sanders Kasi ...
# 83  Christian Bale Harry Melling Gillian Anderson ...
# 84  Rooney Mara Claire Foy Jessie Buckley Sarah Po...
# 85  Tom Hanks Mariana Treviño Rachel Keller Marc F...
# 86  Anna Kendrick Kaniehtiio Horn Charlie Carrick ...
#
# [282 rows x 7 columns]

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2023"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0]

# %%
df=pd.concat([df1,df2,df3,df4])

# %%
df
# Out:
#              Opening  Opening.1                 Title  \
# 0      J A N U A R Y          6                 M3GAN
# 1      J A N U A R Y          6           The Old Way
# 2      J A N U A R Y         11  The Devil Conspiracy
# 3      J A N U A R Y         13                 Plane
# 4      J A N U A R Y         13           House Party
# ..               ...        ...                   ...
# 100  D E C E M B E R         22                Memory
# 101  D E C E M B E R         25      The Color Purple
# 102  D E C E M B E R         25  The Boys in the Boat
# 103  D E C E M B E R         25               Ferrari
# 104  D E C E M B E R         29            Good Grief
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / A...
# 1                           Saban Films / Saturn Films
# 2                                 Samuel Goldwyn Films
# 3    Lionsgate / MadRiver Pictures / Di Bonaventura...
# 4              Warner Bros. Pictures / New Line Cinema
# ..                                                 ...
# 100                       Ketchup Entertainment / Mubi
# 101  Warner Bros. Pictures / Amblin Entertainment /...
# 102          Metro-Goldwyn-Mayer / Smokehouse Pictures
# 103            Neon / STXfilms / Ketchup Entertainment
# 104                                            Netflix
#
#                                          Cast and crew   Ref.
# 0    Gerard Johnstone (director); Akela Cooper (scr...    [3]
# 1    Brett Donowho (director); Carl W. Lucas (scree...    [4]
# 2    Nathan Frankowski (director); Ed Alan (screenp...    [5]
# 3    Jean-François Richet (director); Charles Cummi...    [6]
# 4    Calmatic (director); Jamal Olori, Stephen Glov...    [7]
# ..                                                 ...    ...
# 100  Michel Franco (director/screenplay); Jessica C...  [325]
# 101  Blitz Bazawule (director), Marcus Gardley (scr...  [326]
# 102  George Clooney (director), Mark L. Smith (scre...  [327]
# 103  Michael Mann (director), Troy Kennedy Martin (...  [328]
# 104  Dan Levy (director/screenplay); Dan Levy, Ruth...  [329]
#
# [343 rows x 6 columns]

# %%
df_2023 = df[['Title','Cast and crew']]

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in /usr/local/lib/python3.10/dist-packages (1.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tmdbv3api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (2024.6.2)

# %%
from tmdbv3api import TMDb
import json
import requests
import os
from dotenv import load_dotenv

load_dotenv()

tmdb = TMDb()
tmdb.api_key = os.getenv('API_KEY')

# %%
from tmdbv3api import Movie
import numpy as np
import requests

tmdb_movie = Movie()

def get_genre(x):
    genres = []
    try:
        result = tmdb_movie.search(x)
        if not result:
            return np.NaN
        else:
            movie_id = result[0].id
            response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb_movie.api_key))
            data_json = response.json()
            if 'genres' in data_json and data_json['genres']:
                genre_str = " "
                for i in range(len(data_json['genres'])):
                    genres.append(data_json['genres'][i]['name'])
                return genre_str.join(genres)
            else:
                return np.NaN
    except Exception as e:
        print(f"Error processing title '{x}': {e}")
        return np.NaN

# %%
df_2023['genres'] = df_2023['Title'].map(lambda x: get_genre(str(x)))
# Out:
# <ipython-input-73-2ed0b991c088>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['genres'] = df_2023['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2023
# Out:
#                     Title                                      Cast and crew  \
# 0                   M3GAN  Gerard Johnstone (director); Akela Cooper (scr...
# 1             The Old Way  Brett Donowho (director); Carl W. Lucas (scree...
# 2    The Devil Conspiracy  Nathan Frankowski (director); Ed Alan (screenp...
# 3                   Plane  Jean-François Richet (director); Charles Cummi...
# 4             House Party  Calmatic (director); Jamal Olori, Stephen Glov...
# ..                    ...                                                ...
# 100                Memory  Michel Franco (director/screenplay); Jessica C...
# 101      The Color Purple  Blitz Bazawule (director), Marcus Gardley (scr...
# 102  The Boys in the Boat  George Clooney (director), Mark L. Smith (scre...
# 103               Ferrari  Michael Mann (director), Troy Kennedy Martin (...
# 104            Good Grief  Dan Levy (director/screenplay); Dan Levy, Ruth...
#
#                                       genres
# 0                     Science Fiction Horror
# 1                              Western Drama
# 2    Horror Fantasy Science Fiction Thriller
# 3                                     Action
# 4                                     Comedy
# ..                                       ...
# 100                    Action Thriller Crime
# 101                                      NaN
# 102                            Drama History
# 103                            History Drama
# 104                             Comedy Drama
#
# [343 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2023['director_name'] = df_2023['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-76-6179b260bd79>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['director_name'] = df_2023['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2023['actor_1_name'] = df_2023['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# <ipython-input-78-07af9e2bc7c7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['actor_1_name'] = df_2023['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2023['actor_2_name'] = df_2023['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2023['actor_3_name'] = df_2023['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2023 = df_2023.rename(columns={'Title':'movie_title'})

# %%
new_df23 = df_2023.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df23
# Out:
#             director_name      actor_1_name          actor_2_name  \
# 0        Gerard Johnstone  Allison Williams         Violet McGraw
# 1           Brett Donowho      Nicolas Cage  Ryan Kiera Armstrong
# 2       Nathan Frankowski   Alice Orr-Ewing             Joe Doyle
# 3    Jean-François Richet     Gerard Butler           Mike Colter
# 4                Calmatic        Tosin Cole        Jacob Latimore
# ..                    ...               ...                   ...
# 100         Michel Franco  Jessica Chastain       Peter Sarsgaard
# 101        Blitz Bazawule  Fantasia Barrino      Taraji P. Henson
# 102        George Clooney     Callum Turner         Joel Edgerton
# 103          Michael Mann       Adam Driver         Penelope Cruz
# 104              Dan Levy          Dan Levy            Ruth Negga
#
#          actor_3_name                                   genres  \
# 0         Amie Donald                   Science Fiction Horror
# 1                 NaN                            Western Drama
# 2        Eveline Hall  Horror Fantasy Science Fiction Thriller
# 3            Yoson An                                   Action
# 4        Karen Obilom                                   Comedy
# ..                ...                                      ...
# 100     Merritt Wever                    Action Thriller Crime
# 101   Danielle Brooks                                      NaN
# 102    Peter Guinness                            Drama History
# 103  Shailene Woodley                            History Drama
# 104      Himesh Patel                             Comedy Drama
#
#               movie_title
# 0                   M3GAN
# 1             The Old Way
# 2    The Devil Conspiracy
# 3                   Plane
# 4             House Party
# ..                    ...
# 100                Memory
# 101      The Color Purple
# 102  The Boys in the Boat
# 103               Ferrari
# 104            Good Grief
#
# [343 rows x 6 columns]

# %%
new_df23['comb'] = new_df23['actor_1_name'] + ' ' + new_df23['actor_2_name'] + ' '+ new_df23['actor_3_name'] + ' '+ new_df23['director_name'] +' ' + new_df23['genres']

# %%
new_df23.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      3
# actor_3_name     20
# genres            2
# movie_title       0
# comb             22
# dtype: int64

# %%
new_df23=new_df23.dropna(how='any')

# %%
new_df23.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df23
# Out:
#             director_name      actor_1_name       actor_2_name  \
# 0        Gerard Johnstone  Allison Williams      Violet McGraw
# 2       Nathan Frankowski   Alice Orr-Ewing          Joe Doyle
# 3    Jean-François Richet     Gerard Butler        Mike Colter
# 4                Calmatic        Tosin Cole     Jacob Latimore
# 5              John Hyams      Gideon Adlon  Bethlehem Million
# ..                    ...               ...                ...
# 99          Matthew Brown   Anthony Hopkins      Matthew Goode
# 100         Michel Franco  Jessica Chastain    Peter Sarsgaard
# 102        George Clooney     Callum Turner      Joel Edgerton
# 103          Michael Mann       Adam Driver      Penelope Cruz
# 104              Dan Levy          Dan Levy         Ruth Negga
#
#          actor_3_name                                   genres  \
# 0         Amie Donald                   Science Fiction Horror
# 2        Eveline Hall  Horror Fantasy Science Fiction Thriller
# 3            Yoson An                                   Action
# 4        Karen Obilom                                   Comedy
# 5       Marc Menchaca                  Horror Thriller Mystery
# ..                ...                                      ...
# 99     Liv Lisa Fries                                    Drama
# 100     Merritt Wever                    Action Thriller Crime
# 102    Peter Guinness                            Drama History
# 103  Shailene Woodley                            History Drama
# 104      Himesh Patel                             Comedy Drama
#
#               movie_title                                               comb
# 0                   M3GAN  Allison Williams Violet McGraw Amie Donald Ger...
# 2    The Devil Conspiracy  Alice Orr-Ewing Joe Doyle Eveline Hall Nathan ...
# 3                   Plane  Gerard Butler Mike Colter Yoson An Jean-Franço...
# 4             House Party  Tosin Cole Jacob Latimore Karen Obilom Calmati...
# 5                    Sick  Gideon Adlon Bethlehem Million Marc Menchaca J...
# ..                    ...                                                ...
# 99   Freud's Last Session  Anthony Hopkins Matthew Goode Liv Lisa Fries M...
# 100                Memory  Jessica Chastain Peter Sarsgaard Merritt Wever...
# 102  The Boys in the Boat  Callum Turner Joel Edgerton Peter Guinness Geo...
# 103               Ferrari  Adam Driver Penelope Cruz Shailene Woodley Mic...
# 104            Good Grief  Dan Levy Ruth Negga Himesh Patel Dan Levy Come...
#
# [321 rows x 7 columns]

# %%
my_df=pd.concat([new_df21,new_df22,new_df23])

# %%
my_df
# Out:
#       director_name        actor_1_name          actor_2_name  \
# 0    Roseanne Liang  Chloë Grace Moretz     Taylor John Smith
# 1     Anthony Leone             Amy Cay  Brian Patrick Butler
# 2         Yaniv Raz   Lucas Jade Zumann        Taylor Russell
# 3     Ramin Bahrani       Adarsh Gourav         Rajkummar Rao
# 4        Doug Liman       Anne Hathaway      Chiwetel Ejiofor
# ..              ...                 ...                   ...
# 99    Matthew Brown     Anthony Hopkins         Matthew Goode
# 100   Michel Franco    Jessica Chastain       Peter Sarsgaard
# 102  George Clooney       Callum Turner         Joel Edgerton
# 103    Michael Mann         Adam Driver         Penelope Cruz
# 104        Dan Levy            Dan Levy            Ruth Negga
#
#               actor_3_name                             genres  \
# 0             Beulah Koale                  Horror Action War
# 1       Michael C. Burgess  Adventure Family TV Movie Western
# 2             Chase Stokes                       Comedy Drama
# 3    Priyanka Chopra Jonas                              Drama
# 4         Stephen Merchant               Comedy Crime Romance
# ..                     ...                                ...
# 99          Liv Lisa Fries                              Drama
# 100          Merritt Wever              Action Thriller Crime
# 102         Peter Guinness                      Drama History
# 103       Shailene Woodley                      History Drama
# 104           Himesh Patel                       Comedy Drama
#
#                          movie_title  \
# 0                shadow in the cloud
# 1                            hacksaw
# 2    dr. bird's advice for sad poets
# 3                    the white tiger
# 4                        locked down
# ..                               ...
# 99              Freud's Last Session
# 100                           Memory
# 102             The Boys in the Boat
# 103                          Ferrari
# 104                       Good Grief
#
#                                                   comb
# 0    Chloë Grace Moretz Taylor John Smith Beulah Ko...
# 1    Amy Cay Brian Patrick Butler Michael C. Burges...
# 2    Lucas Jade Zumann Taylor Russell Chase Stokes ...
# 3    Adarsh Gourav Rajkummar Rao Priyanka Chopra Jo...
# 4    Anne Hathaway Chiwetel Ejiofor Stephen Merchan...
# ..                                                 ...
# 99   Anthony Hopkins Matthew Goode Liv Lisa Fries M...
# 100  Jessica Chastain Peter Sarsgaard Merritt Wever...
# 102  Callum Turner Joel Edgerton Peter Guinness Geo...
# 103  Adam Driver Penelope Cruz Shailene Woodley Mic...
# 104  Dan Levy Ruth Negga Himesh Patel Dan Levy Come...
#
# [940 rows x 7 columns]

# %%
old_df=pd.read_csv('updated_data.csv')

# %%
old_df
# Out:
#                        director_name           actor_1_name    actor_2_name  \
# 0     Joachim Rønning Espen Sandberg            Johnny Depp   Javier Bardem
# 1                        Zack Snyder            Ben Affleck    Henry Cavill
# 2                      Taika Waititi        Chris Hemsworth  Tom Hiddleston
# 3                         James Gunn            Chris Pratt     Zoe Saldana
# 4                      Sean McNamara         Pierce Brosnan    William Hurt
# ...                              ...                    ...             ...
# 6090                     Pete Docter             Jamie Foxx        Tina Fey
# 6091                Robert Rodriguez  Priyanka Chopra Jonas    Pedro Pascal
# 6092                     Regina King      Kingsley Ben-Adir       Eli Goree
# 6093                 Emerald Fennell         Carey Mulligan      Bo Burnham
# 6094                Kornél Mundruczó          Vanessa Kirby    Shia LaBeouf
#
#          actor_3_name                           genres  \
# 0       Geoffrey Rush  Adventure Action Fantasy Comedy
# 1           Gal Gadot  Action Adventure Fantasy Sci-Fi
# 2      Cate Blanchett  Action Adventure Fantasy Sci-Fi
# 3       Dave Bautista   Action Adventure Comedy Sci-Fi
# 4     Benjamin Walker         Fantasy Action Adventure
# ...               ...                              ...
# 6090    Graham Norton  Animation Family Comedy Fantasy
# 6091    YaYa Gosselin     Family Action Fantasy Comedy
# 6092      Aldis Hodge                            Drama
# 6093      Alison Brie             Thriller Crime Drama
# 6094     Molly Parker                            Drama
#
#                                            movie_title  \
# 0     pirates of the caribbean: dead men tell no tales
# 1                                       justice league
# 2                                       thor: ragnarok
# 3                       guardians of the galaxy vol. 2
# 4                                  the king's daughter
# ...                                                ...
# 6090                                              soul
# 6091                                  we can be heroes
# 6092                             one night in miami...
# 6093                             promising young woman
# 6094                                 pieces of a woman
#
#                                                    comb
# 0     Johnny Depp Javier Bardem Geoffrey Rush Joachi...
# 1     Ben Affleck Henry Cavill Gal Gadot Zack Snyder...
# 2     Chris Hemsworth Tom Hiddleston Cate Blanchett ...
# 3     Chris Pratt Zoe Saldana Dave Bautista James Gu...
# 4     Pierce Brosnan William Hurt Benjamin Walker Se...
# ...                                                 ...
# 6090  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 6091  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 6092  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 6093  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 6094  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [6095 rows x 7 columns]

# %%
last_df=pd.concat([old_df,my_df])

# %%
last_df
# Out:
#                       director_name      actor_1_name     actor_2_name  \
# 0    Joachim Rønning Espen Sandberg       Johnny Depp    Javier Bardem
# 1                       Zack Snyder       Ben Affleck     Henry Cavill
# 2                     Taika Waititi   Chris Hemsworth   Tom Hiddleston
# 3                        James Gunn       Chris Pratt      Zoe Saldana
# 4                     Sean McNamara    Pierce Brosnan     William Hurt
# ..                              ...               ...              ...
# 99                    Matthew Brown   Anthony Hopkins    Matthew Goode
# 100                   Michel Franco  Jessica Chastain  Peter Sarsgaard
# 102                  George Clooney     Callum Turner    Joel Edgerton
# 103                    Michael Mann       Adam Driver    Penelope Cruz
# 104                        Dan Levy          Dan Levy       Ruth Negga
#
#          actor_3_name                           genres  \
# 0       Geoffrey Rush  Adventure Action Fantasy Comedy
# 1           Gal Gadot  Action Adventure Fantasy Sci-Fi
# 2      Cate Blanchett  Action Adventure Fantasy Sci-Fi
# 3       Dave Bautista   Action Adventure Comedy Sci-Fi
# 4     Benjamin Walker         Fantasy Action Adventure
# ..                ...                              ...
# 99     Liv Lisa Fries                            Drama
# 100     Merritt Wever            Action Thriller Crime
# 102    Peter Guinness                    Drama History
# 103  Shailene Woodley                    History Drama
# 104      Himesh Patel                     Comedy Drama
#
#                                           movie_title  \
# 0    pirates of the caribbean: dead men tell no tales
# 1                                      justice league
# 2                                      thor: ragnarok
# 3                      guardians of the galaxy vol. 2
# 4                                 the king's daughter
# ..                                                ...
# 99                               Freud's Last Session
# 100                                            Memory
# 102                              The Boys in the Boat
# 103                                           Ferrari
# 104                                        Good Grief
#
#                                                   comb
# 0    Johnny Depp Javier Bardem Geoffrey Rush Joachi...
# 1    Ben Affleck Henry Cavill Gal Gadot Zack Snyder...
# 2    Chris Hemsworth Tom Hiddleston Cate Blanchett ...
# 3    Chris Pratt Zoe Saldana Dave Bautista James Gu...
# 4    Pierce Brosnan William Hurt Benjamin Walker Se...
# ..                                                 ...
# 99   Anthony Hopkins Matthew Goode Liv Lisa Fries M...
# 100  Jessica Chastain Peter Sarsgaard Merritt Wever...
# 102  Callum Turner Joel Edgerton Peter Guinness Geo...
# 103  Adam Driver Penelope Cruz Shailene Woodley Mic...
# 104  Dan Levy Ruth Negga Himesh Patel Dan Levy Come...
#
# [7035 rows x 7 columns]

# %%
last_df.to_csv('main_data.csv',index=False)
